# %% [markdown]
# # (German Federal Election 2017)
# ## by (Jean-Pierre Distler)
#
# ## Preliminary Wrangling
#
# The dataset contains the results of the german federal election from 2017. The dataset contains 3 files:
# 1. An overall overview of the valid and invalid first and second votes for all electoral districts and the federal state they belong to.
# 2. The second file contains the votes for each party in all electoral districts.
# 3. A shape file containing all electoral districts. This will be used to generate some map plots.
#
# You can find an explanation of the german election system here https://en.wikipedia.org/wiki/Electoral_system_of_Germany
#
# The dataset is in a good shape and doesn't need much cleaning.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpereader

# %matplotlib inline

# %%
# This file contains the overall results per district
df = pd.read_csv('2017_german_election_overall.csv')
# This file contains the result per party and district
df2 = pd.read_csv('2017_german_election_party.csv')
# This file contains shapes for all districts
geometries = shpereader.Reader('Geometrie_Wahlkreise_19DBT_VG250_geo.shp') 
shapes = list(geometries.geometries())

# %% [markdown]
# ##

# %%
df3 = df2.query('party == "Christlich.Soziale.Union.in.Bayern.e.V."')
df4 = df3[df3['votes_second_vote'] != 0]
df4
# Out:
#       Unnamed: 0  area_id                           area_name   state  \
# 1407        1408      212                           Altötting  Bayern
# 1408        1409      213                  Erding – Ebersberg  Bayern
# 1409        1410      214                            Freising  Bayern
# 1410        1411      215                    Fürstenfeldbruck  Bayern
# 1411        1412      216                          Ingolstadt  Bayern
# 1412        1413      217                        München-Nord  Bayern
# 1413        1414      218                         München-Ost  Bayern
# 1414        1415      219                         München-Süd  Bayern
# 1415        1416      220                  München-West/Mitte  Bayern
# 1416        1417      221                        München-Land  Bayern
# 1417        1418      222                           Rosenheim  Bayern
# 1418        1419      223  Bad Tölz-Wolfratshausen – Miesbach  Bayern
# 1419        1420      224       Starnberg – Landsberg am Lech  Bayern
# 1420        1421      225                          Traunstein  Bayern
# 1421        1422      226                            Weilheim  Bayern
# 1422        1423      227                          Deggendorf  Bayern
# 1423        1424      228                            Landshut  Bayern
# 1424        1425      229                              Passau  Bayern
# 1425        1426      230                          Rottal-Inn  Bayern
# 1426        1427      231                           Straubing  Bayern
# 1427        1428      232                              Amberg  Bayern
# 1428        1429      233                          Regensburg  Bayern
# 1429        1430      234                          Schwandorf  Bayern
# 1430        1431      235                              Weiden  Bayern
# 1431        1432      236                             Bamberg  Bayern
# 1432        1433      237                            Bayreuth  Bayern
# 1433        1434      238                              Coburg  Bayern
# 1434        1435      239                                 Hof  Bayern
# 1435        1436      240                            Kulmbach  Bayern
# 1436        1437      241                             Ansbach  Bayern
# 1437        1438      242                            Erlangen  Bayern
# 1438        1439      243                               Fürth  Bayern
# 1439        1440      244                       Nürnberg-Nord  Bayern
# 1440        1441      245                        Nürnberg-Süd  Bayern
# 1441        1442      246                                Roth  Bayern
# 1442        1443      247                       Aschaffenburg  Bayern
# 1443        1444      248                       Bad Kissingen  Bayern
# 1444        1445      249                       Main-Spessart  Bayern
# 1445        1446      250                         Schweinfurt  Bayern
# 1446        1447      251                            Würzburg  Bayern
# 1447        1448      252                      Augsburg-Stadt  Bayern
# 1448        1449      253                       Augsburg-Land  Bayern
# 1449        1450      254                          Donau-Ries  Bayern
# 1450        1451      255                             Neu-Ulm  Bayern
# 1451        1452      256                          Oberallgäu  Bayern
# 1452        1453      257                           Ostallgäu  Bayern
#
#                                         party  votes_first_vote  \
# 1407  Christlich.Soziale.Union.in.Bayern.e.V.             68435
# 1408  Christlich.Soziale.Union.in.Bayern.e.V.             78212
# 1409  Christlich.Soziale.Union.in.Bayern.e.V.             79538
# 1410  Christlich.Soziale.Union.in.Bayern.e.V.             82603
# 1411  Christlich.Soziale.Union.in.Bayern.e.V.             90383
# 1412  Christlich.Soziale.Union.in.Bayern.e.V.             55903
# 1413  Christlich.Soziale.Union.in.Bayern.e.V.             68286
# 1414  Christlich.Soziale.Union.in.Bayern.e.V.             55875
# 1415  Christlich.Soziale.Union.in.Bayern.e.V.             64074
# 1416  Christlich.Soziale.Union.in.Bayern.e.V.             85350
# 1417  Christlich.Soziale.Union.in.Bayern.e.V.             84982
# 1418  Christlich.Soziale.Union.in.Bayern.e.V.             62466
# 1419  Christlich.Soziale.Union.in.Bayern.e.V.             73946
# 1420  Christlich.Soziale.Union.in.Bayern.e.V.             80055
# 1421  Christlich.Soziale.Union.in.Bayern.e.V.             63783
# 1422  Christlich.Soziale.Union.in.Bayern.e.V.             52167
# 1423  Christlich.Soziale.Union.in.Bayern.e.V.             75701
# 1424  Christlich.Soziale.Union.in.Bayern.e.V.             61835
# 1425  Christlich.Soziale.Union.in.Bayern.e.V.             55365
# 1426  Christlich.Soziale.Union.in.Bayern.e.V.             60975
# 1427  Christlich.Soziale.Union.in.Bayern.e.V.             80075
# 1428  Christlich.Soziale.Union.in.Bayern.e.V.             78868
# 1429  Christlich.Soziale.Union.in.Bayern.e.V.             77091
# 1430  Christlich.Soziale.Union.in.Bayern.e.V.             59287
# 1431  Christlich.Soziale.Union.in.Bayern.e.V.             60675
# 1432  Christlich.Soziale.Union.in.Bayern.e.V.             58667
# 1433  Christlich.Soziale.Union.in.Bayern.e.V.             55078
# 1434  Christlich.Soziale.Union.in.Bayern.e.V.             59181
# 1435  Christlich.Soziale.Union.in.Bayern.e.V.             74105
# 1436  Christlich.Soziale.Union.in.Bayern.e.V.             81435
# 1437  Christlich.Soziale.Union.in.Bayern.e.V.             62772
# 1438  Christlich.Soziale.Union.in.Bayern.e.V.             78558
# 1439  Christlich.Soziale.Union.in.Bayern.e.V.             45340
# 1440  Christlich.Soziale.Union.in.Bayern.e.V.             46511
# 1441  Christlich.Soziale.Union.in.Bayern.e.V.             81867
# 1442  Christlich.Soziale.Union.in.Bayern.e.V.             68670
# 1443  Christlich.Soziale.Union.in.Bayern.e.V.             86602
# 1444  Christlich.Soziale.Union.in.Bayern.e.V.             72397
# 1445  Christlich.Soziale.Union.in.Bayern.e.V.             73901
# 1446  Christlich.Soziale.Union.in.Bayern.e.V.             76512
# 1447  Christlich.Soziale.Union.in.Bayern.e.V.             52769
# 1448  Christlich.Soziale.Union.in.Bayern.e.V.             94252
# 1449  Christlich.Soziale.Union.in.Bayern.e.V.             68768
# 1450  Christlich.Soziale.Union.in.Bayern.e.V.             80501
# 1451  Christlich.Soziale.Union.in.Bayern.e.V.             88357
# 1452  Christlich.Soziale.Union.in.Bayern.e.V.             93431
#
#       votes_second_vote
# 1407              55419
# 1408              63526
# 1409              73650
# 1410              75625
# 1411              76234
# 1412              49899
# 1413              58526
# 1414              50674
# 1415              57370
# 1416              73193
# 1417              75181
# 1418              54787
# 1419              67511
# 1420              71213
# 1421              57258
# 1422              48183
# 1423              75522
# 1424              52937
# 1425              52778
# 1426              53711
# 1427              71731
# 1428              74720
# 1429              66827
# 1430              55691
# 1431              56141
# 1432              53064
# 1433              48406
# 1434              48772
# 1435              58108
# 1436              74428
# 1437              52412
# 1438              69468
# 1439              40106
# 1440              40882
# 1441              69739
# 1442              54983
# 1443              75793
# 1444              65243
# 1445              63674
# 1446              67583
# 1447              48422
# 1448              81831
# 1449              63640
# 1450              72098
# 1451              72853
# 1452              79932

# %%
areas = geometries.records()
areas_as_array = []
for area in areas:
    areas_as_array.append(area.attributes)

# %%
party_mapping = {'CDU' : 'Christlich.Demokratische.Union.Deutschlands',
                 'SPD' : 'Sozialdemokratische.Partei.Deutschlands',
                 'Linke' : 'DIE.LINKE',
                 'Grüne' : 'BÜNDNIS.90.DIE.GRÜNEN',
                 'CSU' : 'Christlich.Soziale.Union.in.Bayern.e.V.',
                 'UNION' : 'CDU_CSU',
                 'FDP' : 'Freie.Demokratische.Partei',
                 'AFD' : 'Alternative.für.Deutschland',
                 'Piraten' : 'Piratenpartei.Deutschland',
                 'NPD' : 'Nationaldemokratische.Partei.Deutschlands'}

# %%
df2.loc[(df2.party == party_mapping['CSU']), 'party'] = 'CDU_CSU'
df2.loc[(df2.party == party_mapping['CDU']), 'party'] = 'CDU_CSU'

# %%
df2.head()
# Out:
#    Unnamed: 0  area_id                          area_name               state  \
# 0           1        1              Flensburg – Schleswig  Schleswig-Holstein
# 1           2        2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2           3        3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3           4        4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4           5        5                               Kiel  Schleswig-Holstein
#
#      party  votes_first_vote  votes_second_vote
# 0  CDU_CSU             68102              58307
# 1  CDU_CSU             62260              52933
# 2  CDU_CSU             54812              47367
# 3  CDU_CSU             66625              56584
# 4  CDU_CSU             45691              40011

# %%
def turnout_for_party(party, area):
    temp = df2.query('area_id == @area')
    total_votes = df.query('area_id == @area')['valid_second_votes'].iloc[-1]
    temp = temp.query('party == @party')
    party_votes = temp['votes_second_vote'].iloc[-1]
    
    return  temp#(party_votes / total_votes * 100)

# %%
i = 0
for shape in shapes:
    print(turnout_for_party(party_mapping['UNION'], i + 1))
    i += 1
# Out:
#       Unnamed: 0  area_id              area_name               state    party  \
# 0              1        1  Flensburg – Schleswig  Schleswig-Holstein  CDU_CSU
# 1196        1197        1  Flensburg – Schleswig  Schleswig-Holstein  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 0                68102              58307
# 1196                 0                  0
#       Unnamed: 0  area_id                          area_name  \
# 1              2        2  Nordfriesland – Dithmarschen Nord
# 1197        1198        2  Nordfriesland – Dithmarschen Nord
#
#                    state    party  votes_first_vote  votes_second_vote
# 1     Schleswig-Holstein  CDU_CSU             62260              52933
# 1197  Schleswig-Holstein  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                     area_name               state  \
# 2              3        3  Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 1198        1199        3  Steinburg – Dithmarschen Süd  Schleswig-Holstein
#
#         party  votes_first_vote  votes_second_vote
# 2     CDU_CSU             54812              47367
# 1198  CDU_CSU                 0                  0
#       Unnamed: 0  area_id              area_name               state    party  \
# 3              4        4  Rendsburg-Eckernförde  Schleswig-Holstein  CDU_CSU
# 1199        1200        4  Rendsburg-Eckernförde  Schleswig-Holstein  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 3                66625              56584
# 1199                 0                  0
#       Unnamed: 0  area_id area_name               state    party  \
# 4              5        5      Kiel  Schleswig-Holstein  CDU_CSU
# 1200        1201        5      Kiel  Schleswig-Holstein  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 4                45691              40011
# 1200                 0                  0
#       Unnamed: 0  area_id          area_name               state    party  \
# 5              6        6  Plön – Neumünster  Schleswig-Holstein  CDU_CSU
# 1201        1202        6  Plön – Neumünster  Schleswig-Holstein  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 5                53109              43778
# 1201                 0                  0
#       Unnamed: 0  area_id  area_name               state    party  \
# 6              7        7  Pinneberg  Schleswig-Holstein  CDU_CSU
# 1202        1203        7  Pinneberg  Schleswig-Holstein  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 6                73816              63863
# 1202                 0                  0
#       Unnamed: 0  area_id                  area_name               state  \
# 7              8        8  Segeberg – Stormarn-Mitte  Schleswig-Holstein
# 1203        1204        8  Segeberg – Stormarn-Mitte  Schleswig-Holstein
#
#         party  votes_first_vote  votes_second_vote
# 7     CDU_CSU             78788              66367
# 1203  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                    area_name               state  \
# 8              9        9  Ostholstein – Stormarn-Nord  Schleswig-Holstein
# 1204        1205        9  Ostholstein – Stormarn-Nord  Schleswig-Holstein
#
#         party  votes_first_vote  votes_second_vote
# 8     CDU_CSU             56994              48893
# 1204  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                           area_name  \
# 9             10       10  Herzogtum Lauenburg – Stormarn-Süd
# 1205        1206       10  Herzogtum Lauenburg – Stormarn-Süd
#
#                    state    party  votes_first_vote  votes_second_vote
# 9     Schleswig-Holstein  CDU_CSU             75737              66033
# 1205  Schleswig-Holstein  CDU_CSU                 0                  0
#       Unnamed: 0  area_id area_name               state    party  \
# 10            11       11    Lübeck  Schleswig-Holstein  CDU_CSU
# 1206        1207       11    Lübeck  Schleswig-Holstein  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 10               45447              38262
# 1206                 0                  0
#       Unnamed: 0  area_id                                          area_name  \
# 11            12       12  Schwerin – Ludwigslust-Parchim I – Nordwestmec...
# 1207        1208       12  Schwerin – Ludwigslust-Parchim I – Nordwestmec...
#
#                        state    party  votes_first_vote  votes_second_vote
# 11    Mecklenburg-Vorpommern  CDU_CSU             49734              51082
# 1207  Mecklenburg-Vorpommern  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                                          area_name  \
# 12            13       13  Ludwigslust-Parchim II – Nordwestmecklenburg I...
# 1208        1209       13  Ludwigslust-Parchim II – Nordwestmecklenburg I...
#
#                        state    party  votes_first_vote  votes_second_vote
# 12    Mecklenburg-Vorpommern  CDU_CSU             43452              48841
# 1208  Mecklenburg-Vorpommern  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                       area_name  \
# 13            14       14  Rostock – Landkreis Rostock II
# 1209        1210       14  Rostock – Landkreis Rostock II
#
#                        state    party  votes_first_vote  votes_second_vote
# 13    Mecklenburg-Vorpommern  CDU_CSU             47924              49433
# 1209  Mecklenburg-Vorpommern  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                                   area_name  \
# 14            15       15  Vorpommern-Rügen – Vorpommern-Greifswald I
# 1210        1211       15  Vorpommern-Rügen – Vorpommern-Greifswald I
#
#                        state    party  votes_first_vote  votes_second_vote
# 14    Mecklenburg-Vorpommern  CDU_CSU             73745              55114
# 1210  Mecklenburg-Vorpommern  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                                          area_name  \
# 15            16       16  Mecklenburgische Seenplatte I – Vorpommern-Gre...
# 1211        1212       16  Mecklenburgische Seenplatte I – Vorpommern-Gre...
#
#                        state    party  votes_first_vote  votes_second_vote
# 15    Mecklenburg-Vorpommern  CDU_CSU             48272              51790
# 1211  Mecklenburg-Vorpommern  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                                          area_name  \
# 16            17       17  Mecklenburgische Seenplatte II – Landkreis Ros...
# 1212        1213       17  Mecklenburgische Seenplatte II – Landkreis Ros...
#
#                        state    party  votes_first_vote  votes_second_vote
# 16    Mecklenburg-Vorpommern  CDU_CSU             53593              51042
# 1212  Mecklenburg-Vorpommern  CDU_CSU                 0                  0
#       Unnamed: 0  area_id      area_name    state    party  votes_first_vote  \
# 17            18       18  Hamburg-Mitte  Hamburg  CDU_CSU             42131
# 1213        1214       18  Hamburg-Mitte  Hamburg  CDU_CSU                 0
#
#       votes_second_vote
# 17                40948
# 1213                  0
#       Unnamed: 0  area_id       area_name    state    party  votes_first_vote  \
# 18            19       19  Hamburg-Altona  Hamburg  CDU_CSU             37544
# 1214        1215       19  Hamburg-Altona  Hamburg  CDU_CSU                 0
#
#       votes_second_vote
# 18                36149
# 1214                  0
#       Unnamed: 0  area_id           area_name    state    party  \
# 19            20       20  Hamburg-Eimsbüttel  Hamburg  CDU_CSU
# 1215        1216       20  Hamburg-Eimsbüttel  Hamburg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 19               44422              41784
# 1215                 0                  0
#       Unnamed: 0  area_id     area_name    state    party  votes_first_vote  \
# 20            21       21  Hamburg-Nord  Hamburg  CDU_CSU             59332
# 1216        1217       21  Hamburg-Nord  Hamburg  CDU_CSU                 0
#
#       votes_second_vote
# 20                55664
# 1216                  0
#       Unnamed: 0  area_id         area_name    state    party  \
# 21            22       22  Hamburg-Wandsbek  Hamburg  CDU_CSU
# 1217        1218       22  Hamburg-Wandsbek  Hamburg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 21               50799              49443
# 1217                 0                  0
#       Unnamed: 0  area_id                    area_name    state    party  \
# 22            23       23  Hamburg-Bergedorf – Harburg  Hamburg  CDU_CSU
# 1218        1219       23  Hamburg-Bergedorf – Harburg  Hamburg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 22               43194              42304
# 1218                 0                  0
#       Unnamed: 0  area_id       area_name          state    party  \
# 23            24       24  Aurich – Emden  Niedersachsen  CDU_CSU
# 1219        1220       24  Aurich – Emden  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 23               38518              39539
# 1219                 0                  0
#       Unnamed: 0  area_id area_name          state    party  votes_first_vote  \
# 24            25       25  Unterems  Niedersachsen  CDU_CSU             87406
# 1220        1221       25  Unterems  Niedersachsen  CDU_CSU                 0
#
#       votes_second_vote
# 24                74173
# 1220                  0
#       Unnamed: 0  area_id                             area_name  \
# 25            26       26  Friesland – Wilhelmshaven – Wittmund
# 1221        1222       26  Friesland – Wilhelmshaven – Wittmund
#
#               state    party  votes_first_vote  votes_second_vote
# 25    Niedersachsen  CDU_CSU             44531              45087
# 1221  Niedersachsen  CDU_CSU                 0                  0
#       Unnamed: 0  area_id              area_name          state    party  \
# 26            27       27  Oldenburg – Ammerland  Niedersachsen  CDU_CSU
# 1222        1223       27  Oldenburg – Ammerland  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 26               52596              53418
# 1222                 0                  0
#       Unnamed: 0  area_id                                   area_name  \
# 27            28       28  Delmenhorst – Wesermarsch – Oldenburg-Land
# 1223        1224       28  Delmenhorst – Wesermarsch – Oldenburg-Land
#
#               state    party  votes_first_vote  votes_second_vote
# 27    Niedersachsen  CDU_CSU             57389              56526
# 1223  Niedersachsen  CDU_CSU                 0                  0
#       Unnamed: 0  area_id            area_name          state    party  \
# 28            29       29  Cuxhaven – Stade II  Niedersachsen  CDU_CSU
# 1224        1225       29  Cuxhaven – Stade II  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 28               59926              54162
# 1224                 0                  0
#       Unnamed: 0  area_id               area_name          state    party  \
# 29            30       30  Stade I – Rotenburg II  Niedersachsen  CDU_CSU
# 1225        1226       30  Stade I – Rotenburg II  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 29               67191              58989
# 1225                 0                  0
#       Unnamed: 0  area_id  area_name          state    party  \
# 30            31       31  Mittelems  Niedersachsen  CDU_CSU
# 1226        1227       31  Mittelems  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 30               95810              88307
# 1226                 0                  0
#       Unnamed: 0  area_id             area_name          state    party  \
# 31            32       32  Cloppenburg – Vechta  Niedersachsen  CDU_CSU
# 1227        1228       32  Cloppenburg – Vechta  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 31               93546              86302
# 1227                 0                  0
#       Unnamed: 0  area_id              area_name          state    party  \
# 32            33       33  Diepholz – Nienburg I  Niedersachsen  CDU_CSU
# 1228        1229       33  Diepholz – Nienburg I  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 32               65462              55829
# 1228                 0                  0
#       Unnamed: 0  area_id           area_name          state    party  \
# 33            34       34  Osterholz – Verden  Niedersachsen  CDU_CSU
# 1229        1230       34  Osterholz – Verden  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 33               59561              53037
# 1229                 0                  0
#       Unnamed: 0  area_id                 area_name          state    party  \
# 34            35       35  Rotenburg I – Heidekreis  Niedersachsen  CDU_CSU
# 1230        1231       35  Rotenburg I – Heidekreis  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 34               45505              47521
# 1230                 0                  0
#       Unnamed: 0  area_id area_name          state    party  votes_first_vote  \
# 35            36       36   Harburg  Niedersachsen  CDU_CSU             65224
# 1231        1232       36   Harburg  Niedersachsen  CDU_CSU                 0
#
#       votes_second_vote
# 35                57815
# 1231                  0
#       Unnamed: 0  area_id                     area_name          state  \
# 36            37       37  Lüchow-Dannenberg – Lüneburg  Niedersachsen
# 1232        1233       37  Lüchow-Dannenberg – Lüneburg  Niedersachsen
#
#         party  votes_first_vote  votes_second_vote
# 36    CDU_CSU             46740              43862
# 1232  CDU_CSU                 0                  0
#       Unnamed: 0  area_id       area_name          state    party  \
# 37            38       38  Osnabrück-Land  Niedersachsen  CDU_CSU
# 1233        1234       38  Osnabrück-Land  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 37               68381              60739
# 1233                 0                  0
#       Unnamed: 0  area_id        area_name          state    party  \
# 38            39       39  Stadt Osnabrück  Niedersachsen  CDU_CSU
# 1234        1235       39  Stadt Osnabrück  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 38               60122              53911
# 1234                 0                  0
#       Unnamed: 0  area_id                 area_name          state    party  \
# 39            40       40  Nienburg II – Schaumburg  Niedersachsen  CDU_CSU
# 1235        1236       40  Nienburg II – Schaumburg  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 39               59126              49894
# 1235                 0                  0
#       Unnamed: 0  area_id         area_name          state    party  \
# 40            41       41  Stadt Hannover I  Niedersachsen  CDU_CSU
# 1236        1237       41  Stadt Hannover I  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 40               39487              36401
# 1236                 0                  0
#       Unnamed: 0  area_id          area_name          state    party  \
# 41            42       42  Stadt Hannover II  Niedersachsen  CDU_CSU
# 1237        1238       42  Stadt Hannover II  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 41               42713              36203
# 1237                 0                  0
#       Unnamed: 0  area_id        area_name          state    party  \
# 42            43       43  Hannover-Land I  Niedersachsen  CDU_CSU
# 1238        1239       43  Hannover-Land I  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 42               72275              62825
# 1238                 0                  0
#       Unnamed: 0  area_id       area_name          state    party  \
# 43            44       44  Celle – Uelzen  Niedersachsen  CDU_CSU
# 1239        1240       44  Celle – Uelzen  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 43               68642              58851
# 1239                 0                  0
#       Unnamed: 0  area_id        area_name          state    party  \
# 44            45       45  Gifhorn – Peine  Niedersachsen  CDU_CSU
# 1240        1241       45  Gifhorn – Peine  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 44               60274              56504
# 1240                 0                  0
#       Unnamed: 0  area_id                    area_name          state  \
# 45            46       46  Hameln-Pyrmont – Holzminden  Niedersachsen
# 1241        1242       46  Hameln-Pyrmont – Holzminden  Niedersachsen
#
#         party  votes_first_vote  votes_second_vote
# 45    CDU_CSU             46172              44418
# 1241  CDU_CSU                 0                  0
#       Unnamed: 0  area_id         area_name          state    party  \
# 46            47       47  Hannover-Land II  Niedersachsen  CDU_CSU
# 1242        1243       47  Hannover-Land II  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 46               65816              58987
# 1242                 0                  0
#       Unnamed: 0  area_id   area_name          state    party  \
# 47            48       48  Hildesheim  Niedersachsen  CDU_CSU
# 1243        1244       48  Hildesheim  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 47               60456              54871
# 1243                 0                  0
#       Unnamed: 0  area_id                  area_name          state    party  \
# 48            49       49  Salzgitter – Wolfenbüttel  Niedersachsen  CDU_CSU
# 1244        1245       49  Salzgitter – Wolfenbüttel  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 48               45310              45989
# 1244                 0                  0
#       Unnamed: 0  area_id     area_name          state    party  \
# 49            50       50  Braunschweig  Niedersachsen  CDU_CSU
# 1245        1246       50  Braunschweig  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 49               45867              42524
# 1245                 0                  0
#       Unnamed: 0  area_id              area_name          state    party  \
# 50            51       51  Helmstedt – Wolfsburg  Niedersachsen  CDU_CSU
# 1246        1247       51  Helmstedt – Wolfsburg  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 50               47416              47037
# 1246                 0                  0
#       Unnamed: 0  area_id                     area_name          state  \
# 51            52       52  Goslar – Northeim – Osterode  Niedersachsen
# 1247        1248       52  Goslar – Northeim – Osterode  Niedersachsen
#
#         party  votes_first_vote  votes_second_vote
# 51    CDU_CSU             59285              48034
# 1247  CDU_CSU                 0                  0
#       Unnamed: 0  area_id  area_name          state    party  \
# 52            53       53  Göttingen  Niedersachsen  CDU_CSU
# 1248        1249       53  Göttingen  Niedersachsen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 52               56248              51176
# 1248                 0                  0
#       Unnamed: 0  area_id area_name   state    party  votes_first_vote  \
# 53            54       54  Bremen I  Bremen  CDU_CSU             44908
# 1249        1250       54  Bremen I  Bremen  CDU_CSU                 0
#
#       votes_second_vote
# 53                48322
# 1249                  0
#       Unnamed: 0  area_id                area_name   state    party  \
# 54            55       55  Bremen II – Bremerhaven  Bremen  CDU_CSU
# 1250        1251       55  Bremen II – Bremerhaven  Bremen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 54               35927              34754
# 1250                 0                  0
#       Unnamed: 0  area_id                                    area_name  \
# 55            56       56  Prignitz – Ostprignitz-Ruppin – Havelland I
# 1251        1252       56  Prignitz – Ostprignitz-Ruppin – Havelland I
#
#             state    party  votes_first_vote  votes_second_vote
# 55    Brandenburg  CDU_CSU             36483              35214
# 1251  Brandenburg  CDU_CSU                 0                  0
#       Unnamed: 0  area_id             area_name        state    party  \
# 56            57       57  Uckermark – Barnim I  Brandenburg  CDU_CSU
# 1252        1253       57  Uckermark – Barnim I  Brandenburg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 56               39121              36177
# 1252                 0                  0
#       Unnamed: 0  area_id                 area_name        state    party  \
# 57            58       58  Oberhavel – Havelland II  Brandenburg  CDU_CSU
# 1253        1254       58  Oberhavel – Havelland II  Brandenburg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 57               54454              51965
# 1253                 0                  0
#       Unnamed: 0  area_id                      area_name        state  \
# 58            59       59  Märkisch-Oderland – Barnim II  Brandenburg
# 1254        1255       59  Märkisch-Oderland – Barnim II  Brandenburg
#
#         party  votes_first_vote  votes_second_vote
# 58    CDU_CSU             47594              42106
# 1254  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                                          area_name  \
# 59            60       60  Brandenburg an der Havel – Potsdam-Mittelmark ...
# 1255        1256       60  Brandenburg an der Havel – Potsdam-Mittelmark ...
#
#             state    party  votes_first_vote  votes_second_vote
# 59    Brandenburg  CDU_CSU             39988              35556
# 1255  Brandenburg  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                                          area_name  \
# 60            61       61  Potsdam – Potsdam-Mittelmark II – Teltow-Flämi...
# 1256        1257       61  Potsdam – Potsdam-Mittelmark II – Teltow-Flämi...
#
#             state    party  votes_first_vote  votes_second_vote
# 60    Brandenburg  CDU_CSU             48098              48013
# 1256  Brandenburg  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                                          area_name  \
# 61            62       62  Dahme-Spreewald – Teltow-Fläming III – Oberspr...
# 1257        1258       62  Dahme-Spreewald – Teltow-Fläming III – Oberspr...
#
#             state    party  votes_first_vote  votes_second_vote
# 61    Brandenburg  CDU_CSU             56610              49990
# 1257  Brandenburg  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                      area_name        state  \
# 62            63       63  Frankfurt (Oder) – Oder-Spree  Brandenburg
# 1258        1259       63  Frankfurt (Oder) – Oder-Spree  Brandenburg
#
#         party  votes_first_vote  votes_second_vote
# 62    CDU_CSU             37342              33886
# 1258  CDU_CSU                 0                  0
#       Unnamed: 0  area_id              area_name        state    party  \
# 63            64       64  Cottbus – Spree-Neiße  Brandenburg  CDU_CSU
# 1259        1260       64  Cottbus – Spree-Neiße  Brandenburg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 63               36852              31366
# 1259                 0                  0
#       Unnamed: 0  area_id                               area_name  \
# 64            65       65  Elbe-Elster – Oberspreewald-Lausitz II
# 1260        1261       65  Elbe-Elster – Oberspreewald-Lausitz II
#
#             state    party  votes_first_vote  votes_second_vote
# 64    Brandenburg  CDU_CSU             35630              33571
# 1260  Brandenburg  CDU_CSU                 0                  0
#       Unnamed: 0  area_id area_name           state    party  \
# 65            66       66   Altmark  Sachsen-Anhalt  CDU_CSU
# 1261        1262       66   Altmark  Sachsen-Anhalt  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 65               35644              36021
# 1261                 0                  0
#       Unnamed: 0  area_id                area_name           state    party  \
# 66            67       67  Börde – Jerichower Land  Sachsen-Anhalt  CDU_CSU
# 1262        1263       67  Börde – Jerichower Land  Sachsen-Anhalt  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 66               55120              47411
# 1262                 0                  0
#       Unnamed: 0  area_id area_name           state    party  \
# 67            68       68      Harz  Sachsen-Anhalt  CDU_CSU
# 1263        1264       68      Harz  Sachsen-Anhalt  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 67               51387              47578
# 1263                 0                  0
#       Unnamed: 0  area_id  area_name           state    party  \
# 68            69       69  Magdeburg  Sachsen-Anhalt  CDU_CSU
# 1264        1265       69  Magdeburg  Sachsen-Anhalt  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 68               44016              44612
# 1264                 0                  0
#       Unnamed: 0  area_id            area_name           state    party  \
# 69            70       70  Dessau – Wittenberg  Sachsen-Anhalt  CDU_CSU
# 1265        1266       70  Dessau – Wittenberg  Sachsen-Anhalt  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 69               42768              38736
# 1265                 0                  0
#       Unnamed: 0  area_id area_name           state    party  \
# 70            71       71    Anhalt  Sachsen-Anhalt  CDU_CSU
# 1266        1267       71    Anhalt  Sachsen-Anhalt  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 70               45844              44619
# 1266                 0                  0
#       Unnamed: 0  area_id area_name           state    party  \
# 71            72       72     Halle  Sachsen-Anhalt  CDU_CSU
# 1267        1268       72     Halle  Sachsen-Anhalt  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 71               40688              39832
# 1267                 0                  0
#       Unnamed: 0  area_id                area_name           state    party  \
# 72            73       73  Burgenland – Saalekreis  Sachsen-Anhalt  CDU_CSU
# 1268        1269       73  Burgenland – Saalekreis  Sachsen-Anhalt  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 72               43246              38672
# 1268                 0                  0
#       Unnamed: 0  area_id area_name           state    party  \
# 73            74       74  Mansfeld  Sachsen-Anhalt  CDU_CSU
# 1269        1270       74  Mansfeld  Sachsen-Anhalt  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 73               42727              39755
# 1269                 0                  0
#       Unnamed: 0  area_id     area_name   state    party  votes_first_vote  \
# 74            75       75  Berlin-Mitte  Berlin  CDU_CSU             27537
# 1270        1271       75  Berlin-Mitte  Berlin  CDU_CSU                 0
#
#       votes_second_vote
# 74                27906
# 1270                  0
#       Unnamed: 0  area_id      area_name   state    party  votes_first_vote  \
# 75            76       76  Berlin-Pankow  Berlin  CDU_CSU             36472
# 1271        1272       76  Berlin-Pankow  Berlin  CDU_CSU                 0
#
#       votes_second_vote
# 75                36993
# 1271                  0
#       Unnamed: 0  area_id             area_name   state    party  \
# 76            77       77  Berlin-Reinickendorf  Berlin  CDU_CSU
# 1272        1273       77  Berlin-Reinickendorf  Berlin  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 76               49620              41890
# 1272                 0                  0
#       Unnamed: 0  area_id                             area_name   state  \
# 77            78       78  Berlin-Spandau – Charlottenburg Nord  Berlin
# 1273        1274       78  Berlin-Spandau – Charlottenburg Nord  Berlin
#
#         party  votes_first_vote  votes_second_vote
# 77    CDU_CSU             40356              36703
# 1273  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                   area_name   state    party  \
# 78            79       79  Berlin-Steglitz-Zehlendorf  Berlin  CDU_CSU
# 1274        1275       79  Berlin-Steglitz-Zehlendorf  Berlin  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 78               63057              53277
# 1274                 0                  0
#       Unnamed: 0  area_id                          area_name   state    party  \
# 79            80       80  Berlin-Charlottenburg-Wilmersdorf  Berlin  CDU_CSU
# 1275        1276       80  Berlin-Charlottenburg-Wilmersdorf  Berlin  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 79               47189              40120
# 1275                 0                  0
#       Unnamed: 0  area_id                    area_name   state    party  \
# 80            81       81  Berlin-Tempelhof-Schöneberg  Berlin  CDU_CSU
# 1276        1277       81  Berlin-Tempelhof-Schöneberg  Berlin  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 80               51734              44721
# 1276                 0                  0
#       Unnamed: 0  area_id        area_name   state    party  votes_first_vote  \
# 81            82       82  Berlin-Neukölln  Berlin  CDU_CSU             34490
# 1277        1278       82  Berlin-Neukölln  Berlin  CDU_CSU                 0
#
#       votes_second_vote
# 81                31439
# 1277                  0
#       Unnamed: 0  area_id                                          area_name  \
# 82            83       83  Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...
# 1278        1279       83  Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...
#
#        state    party  votes_first_vote  votes_second_vote
# 82    Berlin  CDU_CSU             20964              23906
# 1278  Berlin  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                area_name   state    party  \
# 83            84       84  Berlin-Treptow-Köpenick  Berlin  CDU_CSU
# 1279        1280       84  Berlin-Treptow-Köpenick  Berlin  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 83               29517              31511
# 1279                 0                  0
#       Unnamed: 0  area_id                   area_name   state    party  \
# 84            85       85  Berlin-Marzahn-Hellersdorf  Berlin  CDU_CSU
# 1280        1281       85  Berlin-Marzahn-Hellersdorf  Berlin  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 84               30476              28620
# 1280                 0                  0
#       Unnamed: 0  area_id           area_name   state    party  \
# 85            86       86  Berlin-Lichtenberg  Berlin  CDU_CSU
# 1281        1282       86  Berlin-Lichtenberg  Berlin  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 85               28828              27259
# 1281                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 86            87       87  Aachen I  Nordrhein-Westfalen  CDU_CSU
# 1282        1283       87  Aachen I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 86               47005              38819
# 1282                 0                  0
#       Unnamed: 0  area_id  area_name                state    party  \
# 87            88       88  Aachen II  Nordrhein-Westfalen  CDU_CSU
# 1283        1284       88  Aachen II  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 87               62399              52658
# 1283                 0                  0
#       Unnamed: 0  area_id  area_name                state    party  \
# 88            89       89  Heinsberg  Nordrhein-Westfalen  CDU_CSU
# 1284        1285       89  Heinsberg  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 88               64122              55605
# 1284                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 89            90       90     Düren  Nordrhein-Westfalen  CDU_CSU
# 1285        1286       90     Düren  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 89               62711              52441
# 1285                 0                  0
#       Unnamed: 0  area_id           area_name                state    party  \
# 90            91       91  Rhein-Erft-Kreis I  Nordrhein-Westfalen  CDU_CSU
# 1286        1287       91  Rhein-Erft-Kreis I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 90               74208              63669
# 1286                 0                  0
#       Unnamed: 0  area_id                         area_name  \
# 91            92       92  Euskirchen – Rhein-Erft-Kreis II
# 1287        1288       92  Euskirchen – Rhein-Erft-Kreis II
#
#                     state    party  votes_first_vote  votes_second_vote
# 91    Nordrhein-Westfalen  CDU_CSU             79499              66506
# 1287  Nordrhein-Westfalen  CDU_CSU                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 92            93       93    Köln I  Nordrhein-Westfalen  CDU_CSU
# 1288        1289       93    Köln I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 92               43683              36584
# 1288                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 93            94       94   Köln II  Nordrhein-Westfalen  CDU_CSU
# 1289        1290       94   Köln II  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 93               68654              56165
# 1289                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 94            95       95  Köln III  Nordrhein-Westfalen  CDU_CSU
# 1290        1291       95  Köln III  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 94               41107              36501
# 1290                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 95            96       96      Bonn  Nordrhein-Westfalen  CDU_CSU
# 1291        1292       96      Bonn  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 95               57330              53334
# 1291                 0                  0
#       Unnamed: 0  area_id           area_name                state    party  \
# 96            97       97  Rhein-Sieg-Kreis I  Nordrhein-Westfalen  CDU_CSU
# 1292        1293       97  Rhein-Sieg-Kreis I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 96               79987              62334
# 1292                 0                  0
#       Unnamed: 0  area_id            area_name                state    party  \
# 97            98       98  Rhein-Sieg-Kreis II  Nordrhein-Westfalen  CDU_CSU
# 1293        1294       98  Rhein-Sieg-Kreis II  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 97               80441              61425
# 1293                 0                  0
#       Unnamed: 0  area_id             area_name                state    party  \
# 98            99       99  Oberbergischer Kreis  Nordrhein-Westfalen  CDU_CSU
# 1294        1295       99  Oberbergischer Kreis  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 98               67603              56556
# 1294                 0                  0
#       Unnamed: 0  area_id                   area_name                state  \
# 99           100      100  Rheinisch-Bergischer Kreis  Nordrhein-Westfalen
# 1295        1296      100  Rheinisch-Bergischer Kreis  Nordrhein-Westfalen
#
#         party  votes_first_vote  votes_second_vote
# 99    CDU_CSU             69134              61539
# 1295  CDU_CSU                 0                  0
#       Unnamed: 0  area_id             area_name                state    party  \
# 100          101      101  Leverkusen – Köln IV  Nordrhein-Westfalen  CDU_CSU
# 1296        1297      101  Leverkusen – Köln IV  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 100              47272              43176
# 1296                 0                  0
#       Unnamed: 0  area_id    area_name                state    party  \
# 101          102      102  Wuppertal I  Nordrhein-Westfalen  CDU_CSU
# 1297        1298      102  Wuppertal I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 101              43803              39328
# 1297                 0                  0
#       Unnamed: 0  area_id                            area_name  \
# 102          103      103  Solingen – Remscheid – Wuppertal II
# 1298        1299      103  Solingen – Remscheid – Wuppertal II
#
#                     state    party  votes_first_vote  votes_second_vote
# 102   Nordrhein-Westfalen  CDU_CSU             61871              51318
# 1298  Nordrhein-Westfalen  CDU_CSU                 0                  0
#       Unnamed: 0  area_id   area_name                state    party  \
# 103          104      104  Mettmann I  Nordrhein-Westfalen  CDU_CSU
# 1299        1300      104  Mettmann I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 103              70762              54128
# 1299                 0                  0
#       Unnamed: 0  area_id    area_name                state    party  \
# 104          105      105  Mettmann II  Nordrhein-Westfalen  CDU_CSU
# 1300        1301      105  Mettmann II  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 104              48689              40603
# 1300                 0                  0
#       Unnamed: 0  area_id     area_name                state    party  \
# 105          106      106  Düsseldorf I  Nordrhein-Westfalen  CDU_CSU
# 1301        1302      106  Düsseldorf I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 105              69273              55052
# 1301                 0                  0
#       Unnamed: 0  area_id      area_name                state    party  \
# 106          107      107  Düsseldorf II  Nordrhein-Westfalen  CDU_CSU
# 1302        1303      107  Düsseldorf II  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 106              47950              40606
# 1302                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 107          108      108   Neuss I  Nordrhein-Westfalen  CDU_CSU
# 1303        1304      108   Neuss I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 107              69658              56967
# 1303                 0                  0
#       Unnamed: 0  area_id        area_name                state    party  \
# 108          109      109  Mönchengladbach  Nordrhein-Westfalen  CDU_CSU
# 1304        1305      109  Mönchengladbach  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 108              57766              46786
# 1304                 0                  0
#       Unnamed: 0  area_id             area_name                state    party  \
# 109          110      110  Krefeld I – Neuss II  Nordrhein-Westfalen  CDU_CSU
# 1305        1306      110  Krefeld I – Neuss II  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 109              65223              54909
# 1305                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 110          111      111   Viersen  Nordrhein-Westfalen  CDU_CSU
# 1306        1307      111   Viersen  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 110              82165              65474
# 1306                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 111          112      112     Kleve  Nordrhein-Westfalen  CDU_CSU
# 1307        1308      112     Kleve  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 111              75376              69692
# 1307                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 112          113      113   Wesel I  Nordrhein-Westfalen  CDU_CSU
# 1308        1309      113   Wesel I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 112              61848              53622
# 1308                 0                  0
#       Unnamed: 0  area_id              area_name                state  \
# 113          114      114  Krefeld II – Wesel II  Nordrhein-Westfalen
# 1309        1310      114  Krefeld II – Wesel II  Nordrhein-Westfalen
#
#         party  votes_first_vote  votes_second_vote
# 113   CDU_CSU             48601              40911
# 1309  CDU_CSU                 0                  0
#       Unnamed: 0  area_id   area_name                state    party  \
# 114          115      115  Duisburg I  Nordrhein-Westfalen  CDU_CSU
# 1310        1311      115  Duisburg I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 114              34053              30746
# 1310                 0                  0
#       Unnamed: 0  area_id    area_name                state    party  \
# 115          116      116  Duisburg II  Nordrhein-Westfalen  CDU_CSU
# 1311        1312      116  Duisburg II  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 115              26585              22852
# 1311                 0                  0
#       Unnamed: 0  area_id               area_name                state  \
# 116          117      117  Oberhausen – Wesel III  Nordrhein-Westfalen
# 1312        1313      117  Oberhausen – Wesel III  Nordrhein-Westfalen
#
#         party  votes_first_vote  votes_second_vote
# 116   CDU_CSU             43077              39141
# 1312  CDU_CSU                 0                  0
#       Unnamed: 0  area_id          area_name                state    party  \
# 117          118      118  Mülheim – Essen I  Nordrhein-Westfalen  CDU_CSU
# 1313        1314      118  Mülheim – Essen I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 117              44219              39857
# 1313                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 118          119      119  Essen II  Nordrhein-Westfalen  CDU_CSU
# 1314        1315      119  Essen II  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 118              28912              25606
# 1314                 0                  0
#       Unnamed: 0  area_id  area_name                state    party  \
# 119          120      120  Essen III  Nordrhein-Westfalen  CDU_CSU
# 1315        1316      120  Essen III  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 119              56393              45826
# 1315                 0                  0
#       Unnamed: 0  area_id         area_name                state    party  \
# 120          121      121  Recklinghausen I  Nordrhein-Westfalen  CDU_CSU
# 1316        1317      121  Recklinghausen I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 120              37792              35108
# 1316                 0                  0
#       Unnamed: 0  area_id          area_name                state    party  \
# 121          122      122  Recklinghausen II  Nordrhein-Westfalen  CDU_CSU
# 1317        1318      122  Recklinghausen II  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 121              46996              41084
# 1317                 0                  0
#       Unnamed: 0  area_id      area_name                state    party  \
# 122          123      123  Gelsenkirchen  Nordrhein-Westfalen  CDU_CSU
# 1318        1319      123  Gelsenkirchen  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 122              29767              26451
# 1318                 0                  0
#       Unnamed: 0  area_id               area_name                state  \
# 123          124      124  Steinfurt I – Borken I  Nordrhein-Westfalen
# 1319        1320      124  Steinfurt I – Borken I  Nordrhein-Westfalen
#
#         party  votes_first_vote  votes_second_vote
# 123   CDU_CSU             78487              67423
# 1319  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                     area_name                state  \
# 124          125      125  Bottrop – Recklinghausen III  Nordrhein-Westfalen
# 1320        1321      125  Bottrop – Recklinghausen III  Nordrhein-Westfalen
#
#         party  votes_first_vote  votes_second_vote
# 124   CDU_CSU             50310              44974
# 1320  CDU_CSU                 0                  0
#       Unnamed: 0  area_id  area_name                state    party  \
# 125          126      126  Borken II  Nordrhein-Westfalen  CDU_CSU
# 1321        1322      126  Borken II  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 125              81491              73881
# 1321                 0                  0
#       Unnamed: 0  area_id                area_name                state  \
# 126          127      127  Coesfeld – Steinfurt II  Nordrhein-Westfalen
# 1322        1323      127  Coesfeld – Steinfurt II  Nordrhein-Westfalen
#
#         party  votes_first_vote  votes_second_vote
# 126   CDU_CSU             79677              68636
# 1322  CDU_CSU                 0                  0
#       Unnamed: 0  area_id      area_name                state    party  \
# 127          128      128  Steinfurt III  Nordrhein-Westfalen  CDU_CSU
# 1323        1324      128  Steinfurt III  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 127              67675              57214
# 1323                 0                  0
#       Unnamed: 0  area_id area_name                state    party  \
# 128          129      129   Münster  Nordrhein-Westfalen  CDU_CSU
# 1324        1325      129   Münster  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 128              70605              62275
# 1324                 0                  0
#       Unnamed: 0  area_id  area_name                state    party  \
# 129          130      130  Warendorf  Nordrhein-Westfalen  CDU_CSU
# 1325        1326      130  Warendorf  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 129              75014              65356
# 1325                 0                  0
#       Unnamed: 0  area_id    area_name                state    party  \
# 130          131      131  Gütersloh I  Nordrhein-Westfalen  CDU_CSU
# 1326        1327      131  Gütersloh I  Nordrhein-Westfalen  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 130              81300              67178
# 1326                 0                  0
#       Unnamed: 0  area_id                 area_name                state  \
# 131          132      132  Bielefeld – Gütersloh II  Nordrhein-Westfalen
# 1327        1328      132  Bielefeld – Gütersloh II  Nordrhein-Westfalen
#
#         party  votes_first_vote  votes_second_vote
# 131   CDU_CSU             56481              50989
# 1327  CDU_CSU                 0                  0
# ...
#       Unnamed: 0  area_id      area_name   state    party  votes_first_vote  \
# 252          253      253  Augsburg-Land  Bayern  CDU_CSU                 0
# 1448        1449      253  Augsburg-Land  Bayern  CDU_CSU             94252
#
#       votes_second_vote
# 252                   0
# 1448              81831
#       Unnamed: 0  area_id   area_name   state    party  votes_first_vote  \
# 253          254      254  Donau-Ries  Bayern  CDU_CSU                 0
# 1449        1450      254  Donau-Ries  Bayern  CDU_CSU             68768
#
#       votes_second_vote
# 253                   0
# 1449              63640
#       Unnamed: 0  area_id area_name   state    party  votes_first_vote  \
# 254          255      255   Neu-Ulm  Bayern  CDU_CSU                 0
# 1450        1451      255   Neu-Ulm  Bayern  CDU_CSU             80501
#
#       votes_second_vote
# 254                   0
# 1450              72098
#       Unnamed: 0  area_id   area_name   state    party  votes_first_vote  \
# 255          256      256  Oberallgäu  Bayern  CDU_CSU                 0
# 1451        1452      256  Oberallgäu  Bayern  CDU_CSU             88357
#
#       votes_second_vote
# 255                   0
# 1451              72853
#       Unnamed: 0  area_id  area_name   state    party  votes_first_vote  \
# 256          257      257  Ostallgäu  Bayern  CDU_CSU                 0
# 1452        1453      257  Ostallgäu  Bayern  CDU_CSU             93431
#
#       votes_second_vote
# 256                   0
# 1452              79932
#       Unnamed: 0  area_id    area_name              state    party  \
# 257          258      258  Stuttgart I  Baden-Württemberg  CDU_CSU
# 1453        1454      258  Stuttgart I  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 257              51116              46243
# 1453                 0                  0
#       Unnamed: 0  area_id     area_name              state    party  \
# 258          259      259  Stuttgart II  Baden-Württemberg  CDU_CSU
# 1454        1455      259  Stuttgart II  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 258              46066              40071
# 1454                 0                  0
#       Unnamed: 0  area_id  area_name              state    party  \
# 259          260      260  Böblingen  Baden-Württemberg  CDU_CSU
# 1455        1456      260  Böblingen  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 259              75318              69009
# 1455                 0                  0
#       Unnamed: 0  area_id  area_name              state    party  \
# 260          261      261  Esslingen  Baden-Württemberg  CDU_CSU
# 1456        1457      261  Esslingen  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 260              53661              44747
# 1456                 0                  0
#       Unnamed: 0  area_id  area_name              state    party  \
# 261          262      262  Nürtingen  Baden-Württemberg  CDU_CSU
# 1457        1458      262  Nürtingen  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 261              65566              56106
# 1457                 0                  0
#       Unnamed: 0  area_id  area_name              state    party  \
# 262          263      263  Göppingen  Baden-Württemberg  CDU_CSU
# 1458        1459      263  Göppingen  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 262              50891              45285
# 1458                 0                  0
#       Unnamed: 0  area_id   area_name              state    party  \
# 263          264      264  Waiblingen  Baden-Württemberg  CDU_CSU
# 1459        1460      264  Waiblingen  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 263              64958              58371
# 1459                 0                  0
#       Unnamed: 0  area_id    area_name              state    party  \
# 264          265      265  Ludwigsburg  Baden-Württemberg  CDU_CSU
# 1460        1461      265  Ludwigsburg  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 264              66430              57999
# 1460                 0                  0
#       Unnamed: 0  area_id     area_name              state    party  \
# 265          266      266  Neckar-Zaber  Baden-Württemberg  CDU_CSU
# 1461        1462      266  Neckar-Zaber  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 265              73445              60708
# 1461                 0                  0
#       Unnamed: 0  area_id  area_name              state    party  \
# 266          267      267  Heilbronn  Baden-Württemberg  CDU_CSU
# 1462        1463      267  Heilbronn  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 266              64588              58754
# 1462                 0                  0
#       Unnamed: 0  area_id                    area_name              state  \
# 267          268      268  Schwäbisch Hall – Hohenlohe  Baden-Württemberg
# 1463        1464      268  Schwäbisch Hall – Hohenlohe  Baden-Württemberg
#
#         party  votes_first_vote  votes_second_vote
# 267   CDU_CSU             68589              58085
# 1463  CDU_CSU                 0                  0
#       Unnamed: 0  area_id                    area_name              state  \
# 268          269      269  Backnang – Schwäbisch Gmünd  Baden-Württemberg
# 1464        1465      269  Backnang – Schwäbisch Gmünd  Baden-Württemberg
#
#         party  votes_first_vote  votes_second_vote
# 268   CDU_CSU             55592              47586
# 1464  CDU_CSU                 0                  0
#       Unnamed: 0  area_id           area_name              state    party  \
# 269          270      270  Aalen – Heidenheim  Baden-Württemberg  CDU_CSU
# 1465        1466      270  Aalen – Heidenheim  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 269              77750              64216
# 1465                 0                  0
#       Unnamed: 0  area_id        area_name              state    party  \
# 270          271      271  Karlsruhe-Stadt  Baden-Württemberg  CDU_CSU
# 1466        1467      271  Karlsruhe-Stadt  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 270              45814              44764
# 1466                 0                  0
#       Unnamed: 0  area_id       area_name              state    party  \
# 271          272      272  Karlsruhe-Land  Baden-Württemberg  CDU_CSU
# 1467        1468      272  Karlsruhe-Land  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 271              67491              59234
# 1467                 0                  0
#       Unnamed: 0  area_id area_name              state    party  \
# 272          273      273   Rastatt  Baden-Württemberg  CDU_CSU
# 1468        1469      273   Rastatt  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 272              68253              58793
# 1468                 0                  0
#       Unnamed: 0  area_id   area_name              state    party  \
# 273          274      274  Heidelberg  Baden-Württemberg  CDU_CSU
# 1469        1470      274  Heidelberg  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 273              58020              53139
# 1469                 0                  0
#       Unnamed: 0  area_id area_name              state    party  \
# 274          275      275  Mannheim  Baden-Württemberg  CDU_CSU
# 1470        1471      275  Mannheim  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 274              41809              38743
# 1470                 0                  0
#       Unnamed: 0  area_id          area_name              state    party  \
# 275          276      276  Odenwald – Tauber  Baden-Württemberg  CDU_CSU
# 1471        1472      276  Odenwald – Tauber  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 275              75529              64205
# 1471                 0                  0
#       Unnamed: 0  area_id     area_name              state    party  \
# 276          277      277  Rhein-Neckar  Baden-Württemberg  CDU_CSU
# 1472        1473      277  Rhein-Neckar  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 276              57790              51796
# 1472                 0                  0
#       Unnamed: 0  area_id                area_name              state  \
# 277          278      278  Bruchsal – Schwetzingen  Baden-Württemberg
# 1473        1474      278  Bruchsal – Schwetzingen  Baden-Württemberg
#
#         party  votes_first_vote  votes_second_vote
# 277   CDU_CSU             63167              53147
# 1473  CDU_CSU                 0                  0
#       Unnamed: 0  area_id  area_name              state    party  \
# 278          279      279  Pforzheim  Baden-Württemberg  CDU_CSU
# 1474        1475      279  Pforzheim  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 278              60474              54360
# 1474                 0                  0
#       Unnamed: 0  area_id area_name              state    party  \
# 279          280      280      Calw  Baden-Württemberg  CDU_CSU
# 1475        1476      280      Calw  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 279              65675              56330
# 1475                 0                  0
#       Unnamed: 0  area_id area_name              state    party  \
# 280          281      281  Freiburg  Baden-Württemberg  CDU_CSU
# 1476        1477      281  Freiburg  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 280              50250              50422
# 1476                 0                  0
#       Unnamed: 0  area_id           area_name              state    party  \
# 281          282      282  Lörrach – Müllheim  Baden-Württemberg  CDU_CSU
# 1477        1478      282  Lörrach – Müllheim  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 281              69143              60508
# 1477                 0                  0
#       Unnamed: 0  area_id           area_name              state    party  \
# 282          283      283  Emmendingen – Lahr  Baden-Württemberg  CDU_CSU
# 1478        1479      283  Emmendingen – Lahr  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 282              62478              59782
# 1478                 0                  0
#       Unnamed: 0  area_id  area_name              state    party  \
# 283          284      284  Offenburg  Baden-Württemberg  CDU_CSU
# 1479        1480      284  Offenburg  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 283              73925              57030
# 1479                 0                  0
#       Unnamed: 0  area_id              area_name              state    party  \
# 284          285      285  Rottweil – Tuttlingen  Baden-Württemberg  CDU_CSU
# 1480        1481      285  Rottweil – Tuttlingen  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 284              64551              57094
# 1480                 0                  0
#       Unnamed: 0  area_id         area_name              state    party  \
# 285          286      286  Schwarzwald-Baar  Baden-Württemberg  CDU_CSU
# 1481        1482      286  Schwarzwald-Baar  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 285              58149              46812
# 1481                 0                  0
#       Unnamed: 0  area_id area_name              state    party  \
# 286          287      287  Konstanz  Baden-Württemberg  CDU_CSU
# 1482        1483      287  Konstanz  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 286              70255              52221
# 1482                 0                  0
#       Unnamed: 0  area_id area_name              state    party  \
# 287          288      288  Waldshut  Baden-Württemberg  CDU_CSU
# 1483        1484      288  Waldshut  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 287              56525              53065
# 1483                 0                  0
#       Unnamed: 0  area_id   area_name              state    party  \
# 288          289      289  Reutlingen  Baden-Württemberg  CDU_CSU
# 1484        1485      289  Reutlingen  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 288              63493              53877
# 1484                 0                  0
#       Unnamed: 0  area_id area_name              state    party  \
# 289          290      290  Tübingen  Baden-Württemberg  CDU_CSU
# 1485        1486      290  Tübingen  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 289              56448              48828
# 1485                 0                  0
#       Unnamed: 0  area_id area_name              state    party  \
# 290          291      291       Ulm  Baden-Württemberg  CDU_CSU
# 1486        1487      291       Ulm  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 290              74844              64983
# 1486                 0                  0
#       Unnamed: 0  area_id area_name              state    party  \
# 291          292      292  Biberach  Baden-Württemberg  CDU_CSU
# 1487        1488      292  Biberach  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 291              57823              56162
# 1487                 0                  0
#       Unnamed: 0  area_id area_name              state    party  \
# 292          293      293  Bodensee  Baden-Württemberg  CDU_CSU
# 1488        1489      293  Bodensee  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 292              56165              50422
# 1488                 0                  0
#       Unnamed: 0  area_id   area_name              state    party  \
# 293          294      294  Ravensburg  Baden-Württemberg  CDU_CSU
# 1489        1490      294  Ravensburg  Baden-Württemberg  CDU_CSU
#
#       votes_first_vote  votes_second_vote
# 293              55752              56265
# 1489                 0                  0
#       Unnamed: 0  area_id                 area_name              state  \
# 294          295      295  Zollernalb – Sigmaringen  Baden-Württemberg
# 1490        1491      295  Zollernalb – Sigmaringen  Baden-Württemberg
#
#         party  votes_first_vote  votes_second_vote
# 294   CDU_CSU             61693              52282
# 1490  CDU_CSU                 0                  0
#       Unnamed: 0  area_id    area_name     state    party  votes_first_vote  \
# 295          296      296  Saarbrücken  Saarland  CDU_CSU             45664
# 1491        1492      296  Saarbrücken  Saarland  CDU_CSU                 0
#
#       votes_second_vote
# 295               41395
# 1491                  0
#       Unnamed: 0  area_id  area_name     state    party  votes_first_vote  \
# 296          297      297  Saarlouis  Saarland  CDU_CSU             60069
# 1492        1493      297  Saarlouis  Saarland  CDU_CSU                 0
#
#       votes_second_vote
# 296               52949
# 1492                  0
#       Unnamed: 0  area_id   area_name     state    party  votes_first_vote  \
# 297          298      298  St. Wendel  Saarland  CDU_CSU             57982
# 1493        1494      298  St. Wendel  Saarland  CDU_CSU                 0
#
#       votes_second_vote
# 297               50667
# 1493                  0
#       Unnamed: 0  area_id area_name     state    party  votes_first_vote  \
# 298          299      299   Homburg  Saarland  CDU_CSU             48102
# 1494        1495      299   Homburg  Saarland  CDU_CSU                 0
#
#       votes_second_vote
# 298               44536
# 1494                  0

# %%
def draw_turnout_for_party(party, color):
    fig = plt.figure(figsize=(10, 15))
    ax = plt.axes(projection=ccrs.PlateCarree())

    plt.title('Germany')
    ax.coastlines(resolution='10m')

    i = 0
    for shape in shapes:
        ax.add_geometries([shape], ccrs.PlateCarree(), edgecolor='black', facecolor=color, alpha=turnout_for_party(party, i + 1))
        i += 1
    ax.set_extent([5,16,47,56], ccrs.PlateCarree())

    plt.show();

# %%
draw_turnout_for_party(party_mapping['UNION'], 'black')

# %%
print(areas_as_array[0]['WKR_NAME'])

# %%
fig = plt.figure(figsize=(10, 15))
ax = plt.axes(projection=ccrs.PlateCarree())

plt.title('Germany')
ax.coastlines(resolution='10m')
colors = ['blue', 'yellow']

i = 0
for shape in shapes:
    if i == 0:
        ax.add_geometries([shape], ccrs.PlateCarree(), edgecolor='black', facecolor='red', alpha=0.5)
        i += 1
    else:
        i += 1
        ax.add_geometries([shape], ccrs.PlateCarree(), edgecolor='black', facecolor=np.random.choice(colors), alpha=0.5)     

ax.set_extent([5,16,47,56], ccrs.PlateCarree())

plt.show();

# %%
df.head()

# %% [markdown]
# The column *registered.voters* doesn't follow the naming of the other columns so i will rename it.

# %%
df.rename(columns={'registered.voters' : 'registered_voters'}, inplace=True)
df.head()

# %%
df2.head()

# %%
df2.head()

# %%
df2.party.unique()

# %%
df2.party

# %% [markdown]
# ### What is the structure of your dataset?
#
# The first file **2017_german_election_overall.csv** contains the following variables:
# - **area_id**: An id number for the electoral_state.
# - **area_names**: The name of the electoral districts.
# - **state**: The federal state the district belongs to.
# - **registered.voters**: The number of people in the district that are eligible to vote.
# - **total_votes**: The number of people that voted.
# - **invalid_first_vote**: The number of invalid votes. (E.g. Someone voted for more than one candiate)
# - **valid_first_votes**: The number of valid votes.
# - **invalid_second_votes**: The same as for invalid_first_votes, but this vote is for a party and not for a specific candidate.
# - **valid_second_votes**: The number of valid votes.
#
# The second file **2017_german_election_party.csv** is a per party overvire of all districts and contains the following variables:
# - **area_id**: An id number for the electoral_state.
# - **area_name**: The name of the electoral districts.
# - **state**: The federal state the district belongs to.
# - **party**: The name of the party.
# - **votes_first_vote**: The number of first votes for a party in a specific electoral district
# - **votes_second_vote**:  The number of second votes for a party in a specific electoral district
#
# first and second vote for all parties in a specific district sum up to the number in total_votes of the first file.
# ### What is/are the main feature(s) of interest in your dataset?
#
# 1. The number of voters/non voters overall and if there are districts with a significant deviation.
# 2. The distribution of successfull parties per district and if there is a correlation in a state. Like the CSU traditionally is the election winner in Bavaria.
# 3. Far right parties are growing in europe. Is this trend also visible in the german election and if so is it about the whole country or is it limited to one or more federal states.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# - For the first question: **registered.voters** and **total_votes** as well as the sum per district of **votes_first_vote** and **votes_second_vote**.
# - For the second question: The max and min sum of **votes_first_vote**, **votes_second_votes** for each **party** per district.
# - For the third question: The same as for the second one, but limited to far right parties.

# %% [markdown]
# ### Helper methods

# %%
def turnout_for_state(state):
    temp = df.query('state == @state')
    registered_voters = temp.registered_voters.sum()
    total_votes = temp.total_votes.sum()
    return total_votes / registered_voters * 100

# %% [markdown]
# ## Voter Turnout

# %%
registered_voters = df.registered_voters.sum()
total_votes = df.total_votes.sum()
turnout = total_votes / registered_voters
turnout

# %% [markdown]
# The total turnout is about 76%.
# ### Turnout per federal state

# %%
df.state.value_counts()

# %%
states = ['Nordrhein-Westfalen', 'Bayern', 'Baden-Württemberg', 'Niedersachsen', 'Hessen', 'Sachsen', 'Rheinland-Pfalz', 'Berlin', 'Schleswig-Holstein', 'Brandenburg', 'Sachsen-Anhalt', 'Thüringen', 'Hamburg', 'Mecklenburg-Vorpommern', 'Saarland', 'Bremen']

# %%
turnouts = []
for state in states:
    turnouts.append(turnout_for_state(state))
    
temp_df = pd.DataFrame({'State' : states, 'Turnout' : turnouts})
sns.barplot(x='State', y='Turnout', data=temp_df, color='blue');
plt.xticks(rotation=90);
plt.axhline(turnout * 100);

# %% [markdown]
# ## Univariate Exploration
#
# > In this section, investigate distributions of individual variables. If
# you see unusual points or outliers, take a deeper look to clean things up
# and prepare yourself to look at relationships between variables.

# %%
df.describe()

# %%
sns.distplot(df['total_votes'], label='Total Votes')

# %%
sns.distplot(df['invalid_first_votes'])

# %%
sns.distplot(df['invalid_second_votes'])

# %%
sns.distplot(df['valid_first_votes'])

# %%
sns.distplot(df['valid_second_votes'])

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# The variables of interest follow a normal distribution.
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# There was no need to tidy or change the data.

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %%
df.corr()

# %%
sns.pairplot(df)

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# There is a strong positive correlation between valid first and second votes. And also a less stronger between invalid first and second votes.
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# No.

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!
#
# ### Were there any interesting or surprising interactions between features?
#
# > Your answer here!

# %% [markdown]
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!

# %%
df2.query('area_id == 1')['votes_first_vote'].sum() + df2.query('area_id == 1')['votes_second_vote'].sum()

# %%
df2.shape

# %%
df.shape

# %%
df2.party.unique()

# %%
df.query('state == "Hessen"')

# %%
areas = geometries.records()
next(areas)

# %%
def random_color():
    return list(np.random.choice(range(256), size=3))

# %%
fig = plt.figure(figsize=(10, 15))
ax = plt.axes(projection=ccrs.PlateCarree())

plt.title('Germany')
ax.coastlines(resolution='10m')
colors = ['blue', 'yellow', 'red']

for shape in shapes:
    
    ax.add_geometries([shape], ccrs.PlateCarree(), edgecolor='black', facecolor=np.random.choice(colors), alpha=0.5)
                      
ax.set_extent([5,16,47,56], ccrs.PlateCarree())

plt.show();
